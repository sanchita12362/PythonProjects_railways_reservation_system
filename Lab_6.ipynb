# %%
total_seats = 5

while total_seats > 0:
  print("Seat Booked Successfully")
  print("Remaining Seats:", total_seats - 1)
  total_seats -= 1

print("All Seats Are Filled")
# Out:
# Seat Booked Successfully
# Remaining Seats: 4
# Seat Booked Successfully
# Remaining Seats: 3
# Seat Booked Successfully
# Remaining Seats: 2
# Seat Booked Successfully
# Remaining Seats: 1
# Seat Booked Successfully
# Remaining Seats: 0
# All Seats Are Filled

# %%
print("Available Seat Numbers:")

for seat in range(1, 11):
    print("Seat Number:", seat)
# Out:
# Available Seat Numbers:
# Seat Number: 1
# Seat Number: 2
# Seat Number: 3
# Seat Number: 4
# Seat Number: 5
# Seat Number: 6
# Seat Number: 7
# Seat Number: 8
# Seat Number: 9
# Seat Number: 10

# %%
total_seats = 5

for booking in range(1, 10):
  if booking > total_seats:
    print("No Seats Available")
    break

  if booking == 3:
    print("Checking Special Reservation")
    continue

  pass

  print("Seats", booking, "Booked Sucessfully")
# Out:
# Seats 1 Booked Sucessfully
# Seats 2 Booked Sucessfully
# Checking Special Reservation
# Seats 4 Booked Sucessfully
# Seats 5 Booked Sucessfully
# No Seats Available
